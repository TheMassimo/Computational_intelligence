# %% [markdown]
# Copyright **`(c)`** 2023 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
from random import random
from math import ceil
from functools import reduce
from collections import namedtuple, deque
from queue import PriorityQueue

import numpy as np
from tqdm.auto import tqdm

# %%
State = namedtuple('State', ['taken', 'not_taken'])


def covered(state):
    return reduce(
        np.logical_or,
        [SETS[i] for i in state.taken],
        np.array([False for _ in range(PROBLEM_SIZE)]),
    )


def goal_check(state):
    return np.all(covered(state))

# %%
PROBLEM_SIZE = 10
NUM_SETS = 20
SETS = tuple(np.array([random() < 0.2 for _ in range(PROBLEM_SIZE)]) for _ in range(NUM_SETS))
assert goal_check(State(set(range(NUM_SETS)), set())), "Probelm not solvable"

# %% [markdown]
# ## Depth First

# %%
frontier = deque()
state = State(set(), set(range(NUM_SETS)))
frontier.append(state)

counter = 0
current_state = frontier.pop()
with tqdm(total=None) as pbar:
    while not goal_check(current_state):
        counter += 1
        for action in current_state[1]:
            new_state = State(
                current_state.taken ^ {action},
                current_state.not_taken ^ {action},
            )
            frontier.append(new_state)
        current_state = frontier.pop()
        pbar.update(1)

print(f"Solved in {counter:,} steps ({len(current_state.taken)} tiles)")
# Out:
# 11it [00:00, 11058.81it/s]
# Solved in 11 steps (11 tiles)

# %% [markdown]
# ## Breadth First

# %%
frontier = deque()
state = State(set(), set(range(NUM_SETS)))
frontier.append(state)

counter = 0
current_state = frontier.popleft()
with tqdm(total=None) as pbar:
    while not goal_check(current_state):
        counter += 1
        for action in current_state[1]:
            new_state = State(
                current_state.taken ^ {action},
                current_state.not_taken ^ {action},
            )
            frontier.append(new_state)
        current_state = frontier.popleft()
        pbar.update(1)

print(f"Solved in {counter:,} steps ({len(current_state.taken)} tiles)")
# Out:
# 4459it [00:00, 20759.93it/s]Exception ignored in: <function tqdm.__del__ at 0x000001BA2F8735B0>
# Traceback (most recent call last):
#   File "c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\venv\lib\site-packages\tqdm\std.py", line 1149, in __del__
#     self.close()
#   File "c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\venv\lib\site-packages\tqdm\std.py", line 1278, in close
#     if self.last_print_t < self.start_t + self.delay:
# AttributeError: 'tqdm_asyncio' object has no attribute 'last_print_t'
# 210207it [00:45, 4670.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\General materials\set-covering_path-search.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> counter += 1
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> for action in current_state[1]:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>     new_state = State(
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>         current_state.taken ^ {action},
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>         current_state.not_taken ^ {action},
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a>     frontier.append(new_state)
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> current_state = frontier.popleft()
#
# File <string>:1, in <lambda>(_cls, taken, not_taken)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Greedy Best First

# %%
def f(state):
    missing_size = PROBLEM_SIZE - sum(covered(state))
    return missing_size

# %%
frontier = PriorityQueue()
state = State(set(), set(range(NUM_SETS)))
frontier.put((f(state), state))

counter = 0
_, current_state = frontier.get()
with tqdm(total=None) as pbar:
    while not goal_check(current_state):
        counter += 1
        for action in current_state[1]:
            new_state = State(
                current_state.taken ^ {action},
                current_state.not_taken ^ {action},
            )
            frontier.put((f(new_state), new_state))
        _, current_state = frontier.get()
        pbar.update(1)

print(f"Solved in {counter:,} steps ({len(current_state.taken)} tiles)")
# Out:
# 6it [00:00, 207.22it/s]
# Solved in 6 steps (6 tiles)

# %% [markdown]
# ## A*

# %%
def h(state):
    largest_set_size = max(sum(s) for s in SETS)
    missing_size = PROBLEM_SIZE - sum(covered(state))
    optimistic_estimate = ceil(missing_size / largest_set_size)
    return optimistic_estimate


def h2(state):
    already_covered = covered(state)
    if np.all(already_covered):
        return 0
    largest_set_size = max(sum(np.logical_and(s, np.logical_not(already_covered))) for s in SETS)
    missing_size = PROBLEM_SIZE - sum(already_covered)
    optimistic_estimate = ceil(missing_size / largest_set_size)
    return optimistic_estimate


def h3(state):
    already_covered = covered(state)
    if np.all(already_covered):
        return 0
    missing_size = PROBLEM_SIZE - sum(already_covered)
    candidates = sorted((sum(np.logical_and(s, np.logical_not(already_covered))) for s in SETS), reverse=True)
    taken = 1
    while sum(candidates[:taken]) < missing_size:
        taken += 1
    return taken


def f(state):
    return len(state.taken) + h3(state)

# %%
frontier = PriorityQueue()
state = State(set(), set(range(NUM_SETS)))
frontier.put((f(state), state))

counter = 0
_, current_state = frontier.get()
with tqdm(total=None) as pbar:
    while not goal_check(current_state):
        counter += 1
        for action in current_state[1]:
            new_state = State(
                current_state.taken ^ {action},
                current_state.not_taken ^ {action},
            )
            frontier.put((f(new_state), new_state))
        _, current_state = frontier.get()
        pbar.update(1)

print(f"Solved in {counter:,} steps ({len(current_state.taken)} tiles)")
# Out:
# 3172it [03:46, 14.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\General materials\set-covering_path-search.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> for action in current_state[1]:
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     new_state = State(
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a>         current_state.taken ^ {action},
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a>         current_state.not_taken ^ {action},
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a>     )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a>     frontier.put((f(new_state), new_state))
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> _, current_state = frontier.get()
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> pbar.update(1)
#
# c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\General materials\set-covering_path-search.ipynb Cell 14 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=29'>30</a> def f(state):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=30'>31</a>     return len(state.taken) + h3(state)
#
# c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\General materials\set-covering_path-search.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a> def h3(state):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a>     already_covered = covered(state)
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a>     if np.all(already_covered):
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a>         return 0
#
# c:\Users\maxim\Desktop\Polito\2° Anno\1°Semestre\Computational Intelligence\Computational_intelligence\General materials\set-covering_path-search.ipynb Cell 14 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> State = namedtuple('State', ['taken', 'not_taken'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> def covered(state):
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     return reduce(
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>         np.logical_or,
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>         [SETS[i] for i in state.taken],
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a>         np.array([False for _ in range(PROBLEM_SIZE)]),
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/maxim/Desktop/Polito/2%C2%B0%20Anno/1%C2%B0Semestre/Computational%20Intelligence/Computational_intelligence/General%20materials/set-covering_path-search.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a> def goal_check(state):
#
# KeyboardInterrupt:
